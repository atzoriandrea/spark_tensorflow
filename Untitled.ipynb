# %%
import glob
import os
import cv2
from IPython.core.display import display
from PIL import  Image
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
#config = tf.compat.v1.ConfigProto(
#        device_count = {'GPU': 0}
#    )
#sess = tf.compat.v1.Session(config=config)
from pyspark.sql.functions import udf
config = tf.compat.v1.ConfigProto()
config.gpu_options.allow_growth = True
config.gpu_options.per_process_gpu_memory_fraction=0.6
#gpu_options = tf.GPUOptions(per_process_gpu_memory_fraction=x)
#tf.Session(config=tf.ConfigProto(gpu_options=gpu_options))
session = tf.compat.v1.InteractiveSession(config=config)
#from tensorflow.core import ConfigProto
#from tensorflow.compat.v1 import InteractiveSession

#config = ConfigProto()
#config.gpu_options.allow_growth = True
#session = InteractiveSession(config=config)

# %%
from pyspark.sql import SparkSession
os.environ["JAVA_HOME"] = "/usr/lib/jvm/java-8-openjdk-amd64" # Must corrispond to the current jdk used by colab
os.environ["SPARK_HOME"] = "/opt/spark/" # Must corrispond with the downloaded spark (1st line)
spark = SparkSession.builder.master("spark://192.168.1.38:7077").\
    appName("testTrain").\
    enableHiveSupport().\
    getOrCreate()
sc = spark.sparkContext
sc.setLogLevel("Error")

# %%
#from pyspark.shell import spark
train_dir = "../chest_xray/train"
test_dir = "../chest_xray/test"
val_dir = "dataset/val"

print("Train set:\n========================================")
num_pneumonia = len(os.listdir(os.path.join(train_dir, 'PNEUMONIA')))
num_normal = len(os.listdir(os.path.join(train_dir, 'NORMAL')))
print(f"PNEUMONIA={num_pneumonia}")
print(f"NORMAL={num_normal}")

print("Test set:\n========================================")
print(f"PNEUMONIA={len(os.listdir(os.path.join(test_dir, 'PNEUMONIA')))}")
print(f"NORMAL={len(os.listdir(os.path.join(test_dir, 'NORMAL')))}")

print("Validation set:\n========================================")
print(f"PNEUMONIA={len(os.listdir(os.path.join(val_dir, 'PNEUMONIA')))}")
print(f"NORMAL={len(os.listdir(os.path.join(val_dir, 'NORMAL')))}")
# Out:
# Train set:
# ========================================
# PNEUMONIA=3875
# NORMAL=1341
# Test set:
# ========================================
# PNEUMONIA=390
# NORMAL=234
# Validation set:
# ========================================
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-c8b460258c6f> in <module>
#      15
#      16 print("Validation set:\n========================================")
# ---> 17 print(f"PNEUMONIA={len(os.listdir(os.path.join(val_dir, 'PNEUMONIA')))}")
#      18 print(f"NORMAL={len(os.listdir(os.path.join(val_dir, 'NORMAL')))}")
#      19
#
# FileNotFoundError: [Errno 2] No such file or directory: 'dataset/val/PNEUMONIA'

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

image_generator = ImageDataGenerator(
    rotation_range=20,
    width_shift_range=0.1,
    shear_range=0.1,
    zoom_range=0.1,
    samplewise_center=True,
    samplewise_std_normalization=True
)

# %%
train = image_generator.flow_from_directory(train_dir,
                                            batch_size=8,
                                            shuffle=True,
                                            class_mode='binary',
                                            target_size=(320, 320))
"""
validation = image_generator.flow_from_directory(val_dir,
                                                batch_size=8,
                                                shuffle=True,
                                                class_mode='binary',
                                                target_size=(320, 320))
"""
test = image_generator.flow_from_directory(test_dir,
                                            batch_size=8,
                                            shuffle=True,
                                            class_mode='binary',
                                            target_size=(320, 320))
# Out:
# Found 5216 images belonging to 2 classes.
# Found 624 images belonging to 2 classes.

# %%
import cv2
import sklearn
def random_shuffled_dataset(preprocess):
    directory = preprocess.directory
    train_full_paths = []
    train_full_paths = [cv2.imread(file) for file in glob.glob(directory+"/NORMAL/*.jpeg")]
    train_full_paths.extend([cv2.imread(file) for file in glob.glob(directory+"/PNEUMONIA/*.jpeg")])
    train_set = []
    for image in train_full_paths:
        train_set.append(cv2.resize(image,(320,320)))
    labels = preprocess.labels.tolist()
    a,b = sklearn.utils.shuffle(train_set, labels)
    return np.array(a), np.array(b)
shuffle_train, shuffle_labels_train = random_shuffled_dataset(train)
shuffle_valid, shuffle_labels_valid = random_shuffled_dataset(validation)

# %%
import cv2
import sklearn
def random_shuffled_dataset(preprocess):
    directory = preprocess.directory
    train_full_paths = []
    normals = glob.glob(directory+"/NORMAL/*.jpeg")
    pneumo = glob.glob(directory+"/PNEUMONIA/*.jpeg")
    train_full_paths = [cv2.imread(file) for file in normals[0:7]]
    train_full_paths.extend([cv2.imread(file) for file in pneumo[0:7]])
    train_set = []
    for image in train_full_paths:
        train_set.append(cv2.resize(image,(320,320)))
    zeros = [0] * 7
    ones = [1] * 7
    labels = zeros+ones #preprocess.labels.tolist()
    a,b = sklearn.utils.shuffle(train_set, labels)
    return np.array(a), np.array(b)
shuffle_train, shuffle_labels_train = random_shuffled_dataset(train)
shuffle_valid, shuffle_labels_valid = random_shuffled_dataset(validation)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Conv2D, MaxPool2D, Dropout, Flatten, BatchNormalization


model = Sequential()

model.add(Conv2D(filters=32, kernel_size=(3, 3), input_shape=(320, 320, 3), activation='relu'))
model.add(BatchNormalization())
model.add(Conv2D(filters=32, kernel_size=(3, 3), input_shape=(320, 320, 3), activation='relu'))
model.add(BatchNormalization())
model.add(MaxPool2D(pool_size=(2, 2)))

model.add(Conv2D(filters=64, kernel_size=(3, 3), activation='relu'))
model.add(BatchNormalization())
model.add(Conv2D(filters=64, kernel_size=(3, 3), activation='relu'))
model.add(BatchNormalization())
model.add(MaxPool2D(pool_size=(2, 2)))

model.add(Conv2D(filters=128, kernel_size=(3, 3), activation='relu'))
model.add(BatchNormalization())
model.add(Conv2D(filters=128, kernel_size=(3, 3), activation='relu'))
model.add(BatchNormalization())
model.add(MaxPool2D(pool_size=(2, 2)))

model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.2))

model.add(Dense(1, activation='sigmoid'))

model.compile(loss='binary_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 318, 318, 32)      896
# _________________________________________________________________
# batch_normalization (BatchNo (None, 318, 318, 32)      128
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 316, 316, 32)      9248
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 316, 316, 32)      128
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 158, 158, 32)      0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 156, 156, 64)      18496
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 156, 156, 64)      256
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 154, 154, 64)      36928
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 154, 154, 64)      256
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 77, 77, 64)        0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 75, 75, 128)       73856
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 75, 75, 128)       512
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 73, 73, 128)       147584
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 73, 73, 128)       512
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 36, 36, 128)       0
# _________________________________________________________________
# flatten (Flatten)            (None, 165888)            0
# _________________________________________________________________
# dense (Dense)                (None, 128)               21233792
# _________________________________________________________________
# dropout (Dropout)            (None, 128)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 129
# =================================================================
# Total params: 21,522,721
# Trainable params: 21,521,825
# Non-trainable params: 896
# _________________________________________________________________

# %%
weight_for_0 = num_pneumonia / (num_normal + num_pneumonia)
weight_for_1 = num_normal / (num_normal + num_pneumonia)
class_weight = {0: weight_for_0, 1: weight_for_1}

# %%
c = train[0]
batch = c[0]

# %%
l = batch.tolist()
image_df = spark.read.format("image").load(val_dir+"/NORMAL",)
display(image_df)
# Out:
# DataFrame[image: struct<origin:string,height:int,width:int,nChannels:int,mode:int,data:binary>]

# %%
image_df.select("image.height","image.width","image.nChannels", "image.mode", "image.data").show()
# Out:
# +------+-----+---------+----+--------------------+
# |height|width|nChannels|mode|                data|
# +------+-----+---------+----+--------------------+
# |  1225| 1632|        1|   0|[01 0C 07 07 08 0...|
# |  1302| 1564|        1|   0|[00 00 00 00 00 0...|
# |  1040| 1272|        1|   0|[A9 AB 9C A7 A3 F...|
# |  1416| 1776|        1|   0|[03 00 04 01 05 F...|
# |  1416| 1736|        1|   0|[2E 36 3B 3C 3C F...|
# |   928| 1288|        1|   0|[54 55 5D 60 64 F...|
# |  1104| 1240|        1|   0|[14 16 10 19 14 F...|
# |  1104| 1328|        1|   0|[43 3C 44 38 43 F...|
# +------+-----+---------+----+--------------------+

# %%
#
def pred(img):
    img = img[np.newaxis, ...]
    y = model.predict(img,workers=2,use_multiprocessing=False)
    return y

# %%
#parallel = sc.parallelize(image_df)
rdd = image_df.rdd.flatMap(list)

# %%
image_df.

# %%
p = res.collect()
# Out:
# Traceback (most recent call last):
#   File "/home/andrea/.local/lib/python3.6/site-packages/pyspark/serializers.py", line 468, in dumps
#     return cloudpickle.dumps(obj, pickle_protocol)
#   File "/home/andrea/.local/lib/python3.6/site-packages/pyspark/cloudpickle.py", line 1097, in dumps
#     cp.dump(obj)
#   File "/home/andrea/.local/lib/python3.6/site-packages/pyspark/cloudpickle.py", line 357, in dump
#     return Pickler.dump(self, obj)
#   File "/usr/lib/python3.6/pickle.py", line 409, in dump
#     self.save(obj)
#   File "/usr/lib/python3.6/pickle.py", line 476, in save
#     f(self, obj) # Call unbound method with explicit self
#   File "/usr/lib/python3.6/pickle.py", line 751, in save_tuple
#     save(element)
#   File "/usr/lib/python3.6/pickle.py", line 476, in save
#     f(self, obj) # Call unbound method with explicit self
#   File "/home/andrea/.local/lib/python3.6/site-packages/pyspark/cloudpickle.py", line 501, in save_function
#     self.save_function_tuple(obj)
#   File "/home/andrea/.local/lib/python3.6/site-packages/pyspark/cloudpickle.py", line 730, in save_function_tuple
#     save(state)
#   File "/usr/lib/python3.6/pickle.py", line 476, in save
#     f(self, obj) # Call unbound method with explicit self
#   File "/usr/lib/python3.6/pickle.py", line 821, in save_dict
#     self._batch_setitems(obj.items())
#   File "/usr/lib/python3.6/pickle.py", line 847, in _batch_setitems
#     save(v)
#   File "/usr/lib/python3.6/pickle.py", line 476, in save
#     f(self, obj) # Call unbound method with explicit self
#   File "/usr/lib/python3.6/pickle.py", line 781, in save_list
#     self._batch_appends(obj)
#   File "/usr/lib/python3.6/pickle.py", line 805, in _batch_appends
#     save(x)
#   File "/usr/lib/python3.6/pickle.py", line 476, in save
#     f(self, obj) # Call unbound method with explicit self
#   File "/home/andrea/.local/lib/python3.6/site-packages/pyspark/cloudpickle.py", line 501, in save_function
#     self.save_function_tuple(obj)
#   File "/home/andrea/.local/lib/python3.6/site-packages/pyspark/cloudpickle.py", line 730, in save_function_tuple
#     save(state)
#   File "/usr/lib/python3.6/pickle.py", line 476, in save
#     f(self, obj) # Call unbound method with explicit self
#   File "/usr/lib/python3.6/pickle.py", line 821, in save_dict
#     self._batch_setitems(obj.items())
#   File "/usr/lib/python3.6/pickle.py", line 847, in _batch_setitems
#     save(v)
#   File "/usr/lib/python3.6/pickle.py", line 476, in save
#     f(self, obj) # Call unbound method with explicit self
#   File "/usr/lib/python3.6/pickle.py", line 781, in save_list
#     self._batch_appends(obj)
#   File "/usr/lib/python3.6/pickle.py", line 808, in _batch_appends
#     save(tmp[0])
#   File "/usr/lib/python3.6/pickle.py", line 476, in save
#     f(self, obj) # Call unbound method with explicit self
#   File "/home/andrea/.local/lib/python3.6/site-packages/pyspark/cloudpickle.py", line 496, in save_function
#     self.save_function_tuple(obj)
#   File "/home/andrea/.local/lib/python3.6/site-packages/pyspark/cloudpickle.py", line 730, in save_function_tuple
#     save(state)
#   File "/usr/lib/python3.6/pickle.py", line 476, in save
#     f(self, obj) # Call unbound method with explicit self
#   File "/usr/lib/python3.6/pickle.py", line 821, in save_dict
#     self._batch_setitems(obj.items())
#   File "/usr/lib/python3.6/pickle.py", line 847, in _batch_setitems
#     save(v)
#   File "/usr/lib/python3.6/pickle.py", line 476, in save
#     f(self, obj) # Call unbound method with explicit self
#   File "/usr/lib/python3.6/pickle.py", line 821, in save_dict
#     self._batch_setitems(obj.items())
#   File "/usr/lib/python3.6/pickle.py", line 852, in _batch_setitems
#     save(v)
#   File "/usr/lib/python3.6/pickle.py", line 521, in save
#     self.save_reduce(obj=obj, *rv)
#   File "/usr/lib/python3.6/pickle.py", line 634, in save_reduce
#     save(state)
#   File "/usr/lib/python3.6/pickle.py", line 476, in save
#     f(self, obj) # Call unbound method with explicit self
#   File "/usr/lib/python3.6/pickle.py", line 821, in save_dict
#     self._batch_setitems(obj.items())
#   File "/usr/lib/python3.6/pickle.py", line 847, in _batch_setitems
#     save(v)
#   File "/usr/lib/python3.6/pickle.py", line 476, in save
#     f(self, obj) # Call unbound method with explicit self
#   File "/usr/lib/python3.6/pickle.py", line 781, in save_list
#     self._batch_appends(obj)
#   File "/usr/lib/python3.6/pickle.py", line 805, in _batch_appends
#     save(x)
#   File "/usr/lib/python3.6/pickle.py", line 521, in save
#     self.save_reduce(obj=obj, *rv)
#   File "/usr/lib/python3.6/pickle.py", line 634, in save_reduce
#     save(state)
#   File "/usr/lib/python3.6/pickle.py", line 476, in save
#     f(self, obj) # Call unbound method with explicit self
#   File "/usr/lib/python3.6/pickle.py", line 821, in save_dict
#     self._batch_setitems(obj.items())
#   File "/usr/lib/python3.6/pickle.py", line 847, in _batch_setitems
#     save(v)
#   File "/usr/lib/python3.6/pickle.py", line 476, in save
#     f(self, obj) # Call unbound method with explicit self
#   File "/usr/lib/python3.6/pickle.py", line 781, in save_list
#     self._batch_appends(obj)
#   File "/usr/lib/python3.6/pickle.py", line 808, in _batch_appends
#     save(tmp[0])
#   File "/usr/lib/python3.6/pickle.py", line 521, in save
#     self.save_reduce(obj=obj, *rv)
#   File "/usr/lib/python3.6/pickle.py", line 634, in save_reduce
#     save(state)
#   File "/usr/lib/python3.6/pickle.py", line 476, in save
#     f(self, obj) # Call unbound method with explicit self
#   File "/usr/lib/python3.6/pickle.py", line 821, in save_dict
#     self._batch_setitems(obj.items())
#   File "/usr/lib/python3.6/pickle.py", line 847, in _batch_setitems
#     save(v)
#   File "/usr/lib/python3.6/pickle.py", line 521, in save
#     self.save_reduce(obj=obj, *rv)
#   File "/usr/lib/python3.6/pickle.py", line 634, in save_reduce
#     save(state)
#   File "/usr/lib/python3.6/pickle.py", line 476, in save
#     f(self, obj) # Call unbound method with explicit self
#   File "/usr/lib/python3.6/pickle.py", line 821, in save_dict
#     self._batch_setitems(obj.items())
#   File "/usr/lib/python3.6/pickle.py", line 847, in _batch_setitems
#     save(v)
#   File "/usr/lib/python3.6/pickle.py", line 521, in save
#     self.save_reduce(obj=obj, *rv)
#   File "/usr/lib/python3.6/pickle.py", line 634, in save_reduce
#     save(state)
#   File "/usr/lib/python3.6/pickle.py", line 476, in save
#     f(self, obj) # Call unbound method with explicit self
#   File "/usr/lib/python3.6/pickle.py", line 821, in save_dict
#     self._batch_setitems(obj.items())
#   File "/usr/lib/python3.6/pickle.py", line 847, in _batch_setitems
#     save(v)
#   File "/usr/lib/python3.6/pickle.py", line 521, in save
#     self.save_reduce(obj=obj, *rv)
#   File "/usr/lib/python3.6/pickle.py", line 634, in save_reduce
#     save(state)
#   File "/usr/lib/python3.6/pickle.py", line 476, in save
#     f(self, obj) # Call unbound method with explicit self
#   File "/usr/lib/python3.6/pickle.py", line 821, in save_dict
#     self._batch_setitems(obj.items())
#   File "/usr/lib/python3.6/pickle.py", line 847, in _batch_setitems
#     save(v)
#   File "/usr/lib/python3.6/pickle.py", line 496, in save
#     rv = reduce(self.proto)
# TypeError: can't pickle _thread.RLock objects
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/.local/lib/python3.6/site-packages/pyspark/serializers.py in dumps(self, obj)
#     467         try:
# --> 468             return cloudpickle.dumps(obj, pickle_protocol)
#     469         except pickle.PickleError:
#
# ~/.local/lib/python3.6/site-packages/pyspark/cloudpickle.py in dumps(obj, protocol)
#    1096         cp = CloudPickler(file, protocol=protocol)
# -> 1097         cp.dump(obj)
#    1098         return file.getvalue()
#
# ~/.local/lib/python3.6/site-packages/pyspark/cloudpickle.py in dump(self, obj)
#     356         try:
# --> 357             return Pickler.dump(self, obj)
#     358         except RuntimeError as e:
#
# /usr/lib/python3.6/pickle.py in dump(self, obj)
#     408             self.framer.start_framing()
# --> 409         self.save(obj)
#     410         self.write(STOP)
#
# /usr/lib/python3.6/pickle.py in save(self, obj, save_persistent_id)
#     475         if f is not None:
# --> 476             f(self, obj) # Call unbound method with explicit self
#     477             return
#
# /usr/lib/python3.6/pickle.py in save_tuple(self, obj)
#     750         for element in obj:
# --> 751             save(element)
#     752
#
# /usr/lib/python3.6/pickle.py in save(self, obj, save_persistent_id)
#     475         if f is not None:
# --> 476             f(self, obj) # Call unbound method with explicit self
#     477             return
#
# ~/.local/lib/python3.6/site-packages/pyspark/cloudpickle.py in save_function(self, obj, name)
#     500             if lookedup_by_name is None or lookedup_by_name is not obj:
# --> 501                 self.save_function_tuple(obj)
#     502                 return
#
# ~/.local/lib/python3.6/site-packages/pyspark/cloudpickle.py in save_function_tuple(self, func)
#     729             state['kwdefaults'] = func.__kwdefaults__
# --> 730         save(state)
#     731         write(pickle.TUPLE)
#
# /usr/lib/python3.6/pickle.py in save(self, obj, save_persistent_id)
#     475         if f is not None:
# --> 476             f(self, obj) # Call unbound method with explicit self
#     477             return
#
# /usr/lib/python3.6/pickle.py in save_dict(self, obj)
#     820         self.memoize(obj)
# --> 821         self._batch_setitems(obj.items())
#     822
#
# /usr/lib/python3.6/pickle.py in _batch_setitems(self, items)
#     846                     save(k)
# --> 847                     save(v)
#     848                 write(SETITEMS)
#
# /usr/lib/python3.6/pickle.py in save(self, obj, save_persistent_id)
#     475         if f is not None:
# --> 476             f(self, obj) # Call unbound method with explicit self
#     477             return
#
# /usr/lib/python3.6/pickle.py in save_list(self, obj)
#     780         self.memoize(obj)
# --> 781         self._batch_appends(obj)
#     782
#
# /usr/lib/python3.6/pickle.py in _batch_appends(self, items)
#     804                 for x in tmp:
# --> 805                     save(x)
#     806                 write(APPENDS)
#
# /usr/lib/python3.6/pickle.py in save(self, obj, save_persistent_id)
#     475         if f is not None:
# --> 476             f(self, obj) # Call unbound method with explicit self
#     477             return
#
# ~/.local/lib/python3.6/site-packages/pyspark/cloudpickle.py in save_function(self, obj, name)
#     500             if lookedup_by_name is None or lookedup_by_name is not obj:
# --> 501                 self.save_function_tuple(obj)
#     502                 return
#
# ~/.local/lib/python3.6/site-packages/pyspark/cloudpickle.py in save_function_tuple(self, func)
#     729             state['kwdefaults'] = func.__kwdefaults__
# --> 730         save(state)
#     731         write(pickle.TUPLE)
#
# /usr/lib/python3.6/pickle.py in save(self, obj, save_persistent_id)
#     475         if f is not None:
# --> 476             f(self, obj) # Call unbound method with explicit self
#     477             return
#
# /usr/lib/python3.6/pickle.py in save_dict(self, obj)
#     820         self.memoize(obj)
# --> 821         self._batch_setitems(obj.items())
#     822
#
# /usr/lib/python3.6/pickle.py in _batch_setitems(self, items)
#     846                     save(k)
# --> 847                     save(v)
#     848                 write(SETITEMS)
#
# /usr/lib/python3.6/pickle.py in save(self, obj, save_persistent_id)
#     475         if f is not None:
# --> 476             f(self, obj) # Call unbound method with explicit self
#     477             return
#
# /usr/lib/python3.6/pickle.py in save_list(self, obj)
#     780         self.memoize(obj)
# --> 781         self._batch_appends(obj)
#     782
#
# /usr/lib/python3.6/pickle.py in _batch_appends(self, items)
#     807             elif n:
# --> 808                 save(tmp[0])
#     809                 write(APPEND)
#
# /usr/lib/python3.6/pickle.py in save(self, obj, save_persistent_id)
#     475         if f is not None:
# --> 476             f(self, obj) # Call unbound method with explicit self
#     477             return
#
# ~/.local/lib/python3.6/site-packages/pyspark/cloudpickle.py in save_function(self, obj, name)
#     495                 or themodule is None):
# --> 496             self.save_function_tuple(obj)
#     497             return
#
# ~/.local/lib/python3.6/site-packages/pyspark/cloudpickle.py in save_function_tuple(self, func)
#     729             state['kwdefaults'] = func.__kwdefaults__
# --> 730         save(state)
#     731         write(pickle.TUPLE)
#
# /usr/lib/python3.6/pickle.py in save(self, obj, save_persistent_id)
#     475         if f is not None:
# --> 476             f(self, obj) # Call unbound method with explicit self
#     477             return
#
# /usr/lib/python3.6/pickle.py in save_dict(self, obj)
#     820         self.memoize(obj)
# --> 821         self._batch_setitems(obj.items())
#     822
#
# /usr/lib/python3.6/pickle.py in _batch_setitems(self, items)
#     846                     save(k)
# --> 847                     save(v)
#     848                 write(SETITEMS)
#
# /usr/lib/python3.6/pickle.py in save(self, obj, save_persistent_id)
#     475         if f is not None:
# --> 476             f(self, obj) # Call unbound method with explicit self
#     477             return
#
# /usr/lib/python3.6/pickle.py in save_dict(self, obj)
#     820         self.memoize(obj)
# --> 821         self._batch_setitems(obj.items())
#     822
#
# /usr/lib/python3.6/pickle.py in _batch_setitems(self, items)
#     851                 save(k)
# --> 852                 save(v)
#     853                 write(SETITEM)
#
# /usr/lib/python3.6/pickle.py in save(self, obj, save_persistent_id)
#     520         # Save the reduce() output and finally memoize the object
# --> 521         self.save_reduce(obj=obj, *rv)
#     522
#
# /usr/lib/python3.6/pickle.py in save_reduce(self, func, args, state, listitems, dictitems, obj)
#     633         if state is not None:
# --> 634             save(state)
#     635             write(BUILD)
#
# /usr/lib/python3.6/pickle.py in save(self, obj, save_persistent_id)
#     475         if f is not None:
# --> 476             f(self, obj) # Call unbound method with explicit self
#     477             return
#
# /usr/lib/python3.6/pickle.py in save_dict(self, obj)
#     820         self.memoize(obj)
# --> 821         self._batch_setitems(obj.items())
#     822
#
# /usr/lib/python3.6/pickle.py in _batch_setitems(self, items)
#     846                     save(k)
# --> 847                     save(v)
#     848                 write(SETITEMS)
#
# /usr/lib/python3.6/pickle.py in save(self, obj, save_persistent_id)
#     475         if f is not None:
# --> 476             f(self, obj) # Call unbound method with explicit self
#     477             return
#
# /usr/lib/python3.6/pickle.py in save_list(self, obj)
#     780         self.memoize(obj)
# --> 781         self._batch_appends(obj)
#     782
#
# /usr/lib/python3.6/pickle.py in _batch_appends(self, items)
#     804                 for x in tmp:
# --> 805                     save(x)
#     806                 write(APPENDS)
#
# /usr/lib/python3.6/pickle.py in save(self, obj, save_persistent_id)
#     520         # Save the reduce() output and finally memoize the object
# --> 521         self.save_reduce(obj=obj, *rv)
#     522
#
# /usr/lib/python3.6/pickle.py in save_reduce(self, func, args, state, listitems, dictitems, obj)
#     633         if state is not None:
# --> 634             save(state)
#     635             write(BUILD)
#
# /usr/lib/python3.6/pickle.py in save(self, obj, save_persistent_id)
#     475         if f is not None:
# --> 476             f(self, obj) # Call unbound method with explicit self
#     477             return
#
# /usr/lib/python3.6/pickle.py in save_dict(self, obj)
#     820         self.memoize(obj)
# --> 821         self._batch_setitems(obj.items())
#     822
#
# /usr/lib/python3.6/pickle.py in _batch_setitems(self, items)
#     846                     save(k)
# --> 847                     save(v)
#     848                 write(SETITEMS)
#
# /usr/lib/python3.6/pickle.py in save(self, obj, save_persistent_id)
#     475         if f is not None:
# --> 476             f(self, obj) # Call unbound method with explicit self
#     477             return
#
# /usr/lib/python3.6/pickle.py in save_list(self, obj)
#     780         self.memoize(obj)
# --> 781         self._batch_appends(obj)
#     782
#
# /usr/lib/python3.6/pickle.py in _batch_appends(self, items)
#     807             elif n:
# --> 808                 save(tmp[0])
#     809                 write(APPEND)
#
# /usr/lib/python3.6/pickle.py in save(self, obj, save_persistent_id)
#     520         # Save the reduce() output and finally memoize the object
# --> 521         self.save_reduce(obj=obj, *rv)
#     522
#
# /usr/lib/python3.6/pickle.py in save_reduce(self, func, args, state, listitems, dictitems, obj)
#     633         if state is not None:
# --> 634             save(state)
#     635             write(BUILD)
#
# /usr/lib/python3.6/pickle.py in save(self, obj, save_persistent_id)
#     475         if f is not None:
# --> 476             f(self, obj) # Call unbound method with explicit self
#     477             return
#
# /usr/lib/python3.6/pickle.py in save_dict(self, obj)
#     820         self.memoize(obj)
# --> 821         self._batch_setitems(obj.items())
#     822
#
# /usr/lib/python3.6/pickle.py in _batch_setitems(self, items)
#     846                     save(k)
# --> 847                     save(v)
#     848                 write(SETITEMS)
#
# /usr/lib/python3.6/pickle.py in save(self, obj, save_persistent_id)
#     520         # Save the reduce() output and finally memoize the object
# --> 521         self.save_reduce(obj=obj, *rv)
#     522
#
# /usr/lib/python3.6/pickle.py in save_reduce(self, func, args, state, listitems, dictitems, obj)
#     633         if state is not None:
# --> 634             save(state)
#     635             write(BUILD)
#
# /usr/lib/python3.6/pickle.py in save(self, obj, save_persistent_id)
#     475         if f is not None:
# --> 476             f(self, obj) # Call unbound method with explicit self
#     477             return
#
# /usr/lib/python3.6/pickle.py in save_dict(self, obj)
#     820         self.memoize(obj)
# --> 821         self._batch_setitems(obj.items())
#     822
#
# /usr/lib/python3.6/pickle.py in _batch_setitems(self, items)
#     846                     save(k)
# --> 847                     save(v)
#     848                 write(SETITEMS)
#
# /usr/lib/python3.6/pickle.py in save(self, obj, save_persistent_id)
#     520         # Save the reduce() output and finally memoize the object
# --> 521         self.save_reduce(obj=obj, *rv)
#     522
#
# /usr/lib/python3.6/pickle.py in save_reduce(self, func, args, state, listitems, dictitems, obj)
#     633         if state is not None:
# --> 634             save(state)
#     635             write(BUILD)
#
# /usr/lib/python3.6/pickle.py in save(self, obj, save_persistent_id)
#     475         if f is not None:
# --> 476             f(self, obj) # Call unbound method with explicit self
#     477             return
#
# /usr/lib/python3.6/pickle.py in save_dict(self, obj)
#     820         self.memoize(obj)
# --> 821         self._batch_setitems(obj.items())
#     822
#
# /usr/lib/python3.6/pickle.py in _batch_setitems(self, items)
#     846                     save(k)
# --> 847                     save(v)
#     848                 write(SETITEMS)
#
# /usr/lib/python3.6/pickle.py in save(self, obj, save_persistent_id)
#     520         # Save the reduce() output and finally memoize the object
# --> 521         self.save_reduce(obj=obj, *rv)
#     522
#
# /usr/lib/python3.6/pickle.py in save_reduce(self, func, args, state, listitems, dictitems, obj)
#     633         if state is not None:
# --> 634             save(state)
#     635             write(BUILD)
#
# /usr/lib/python3.6/pickle.py in save(self, obj, save_persistent_id)
#     475         if f is not None:
# --> 476             f(self, obj) # Call unbound method with explicit self
#     477             return
#
# /usr/lib/python3.6/pickle.py in save_dict(self, obj)
#     820         self.memoize(obj)
# --> 821         self._batch_setitems(obj.items())
#     822
#
# /usr/lib/python3.6/pickle.py in _batch_setitems(self, items)
#     846                     save(k)
# --> 847                     save(v)
#     848                 write(SETITEMS)
#
# /usr/lib/python3.6/pickle.py in save(self, obj, save_persistent_id)
#     495             if reduce is not None:
# --> 496                 rv = reduce(self.proto)
#     497             else:
#
# TypeError: can't pickle _thread.RLock objects
#
# During handling of the above exception, another exception occurred:
#
# PicklingError                             Traceback (most recent call last)
# <ipython-input-17-116d78199973> in <module>
# ----> 1 p = res.collect()
#
# ~/.local/lib/python3.6/site-packages/pyspark/rdd.py in collect(self)
#     887         """
#     888         with SCCallSiteSync(self.context) as css:
# --> 889             sock_info = self.ctx._jvm.PythonRDD.collectAndServe(self._jrdd.rdd())
#     890         return list(_load_from_socket(sock_info, self._jrdd_deserializer))
#     891
#
# ~/.local/lib/python3.6/site-packages/pyspark/rdd.py in _jrdd(self)
#    2627
#    2628         wrapped_func = _wrap_function(self.ctx, self.func, self._prev_jrdd_deserializer,
# -> 2629                                       self._jrdd_deserializer, profiler)
#    2630         python_rdd = self.ctx._jvm.PythonRDD(self._prev_jrdd.rdd(), wrapped_func,
#    2631                                              self.preservesPartitioning, self.is_barrier)
#
# ~/.local/lib/python3.6/site-packages/pyspark/rdd.py in _wrap_function(sc, func, deserializer, serializer, profiler)
#    2515     assert serializer, "serializer should not be empty"
#    2516     command = (func, profiler, deserializer, serializer)
# -> 2517     pickled_command, broadcast_vars, env, includes = _prepare_for_python_RDD(sc, command)
#    2518     return sc._jvm.PythonFunction(bytearray(pickled_command), env, includes, sc.pythonExec,
#    2519                                   sc.pythonVer, broadcast_vars, sc._javaAccumulator)
#
# ~/.local/lib/python3.6/site-packages/pyspark/rdd.py in _prepare_for_python_RDD(sc, command)
#    2501     # the serialized command will be compressed by broadcast
#    2502     ser = CloudPickleSerializer()
# -> 2503     pickled_command = ser.dumps(command)
#    2504     if len(pickled_command) > sc._jvm.PythonUtils.getBroadcastThreshold(sc._jsc):  # Default 1M
#    2505         # The broadcast will have same life cycle as created PythonRDD
#
# ~/.local/lib/python3.6/site-packages/pyspark/serializers.py in dumps(self, obj)
#     476                 msg = "Could not serialize object: %s: %s" % (e.__class__.__name__, emsg)
#     477             print_exec(sys.stderr)
# --> 478             raise pickle.PicklingError(msg)
#     479
#     480
#
# PicklingError: Could not serialize object: TypeError: can't pickle _thread.RLock objects

# %%
z = rdd.map(model.predict_on_batch, preservesPartitioning=True)

# %%
v = v[np.newaxis, ...]
y = model.predict(v, batch_size=1)

# %%
model.fit(train, epochs=20,validation_data=validation, class_weight=class_weight)
# Out:
# Epoch 1/20
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0190s vs `on_train_batch_end` time: 0.0309s). Check your callbacks.
# 652/652 [==============================] - 182s 279ms/step - loss: 0.4907 - accuracy: 0.8622 - val_loss: 0.8171 - val_accuracy: 0.8750
# Epoch 2/20
# 652/652 [==============================] - 116s 179ms/step - loss: 0.1453 - accuracy: 0.9072 - val_loss: 0.6204 - val_accuracy: 0.8125
# Epoch 3/20
# 652/652 [==============================] - 118s 181ms/step - loss: 0.1176 - accuracy: 0.9070 - val_loss: 1.0676 - val_accuracy: 0.7500
# Epoch 4/20
# 652/652 [==============================] - 117s 180ms/step - loss: 0.1645 - accuracy: 0.9162 - val_loss: 252.4853 - val_accuracy: 0.5000
# Epoch 5/20
# 652/652 [==============================] - 119s 182ms/step - loss: 0.1435 - accuracy: 0.9032 - val_loss: 1.6297 - val_accuracy: 0.5625
# Epoch 6/20
# 652/652 [==============================] - 117s 180ms/step - loss: 0.0836 - accuracy: 0.9319 - val_loss: 0.4701 - val_accuracy: 0.9375
# Epoch 7/20
# 652/652 [==============================] - 120s 184ms/step - loss: 0.0884 - accuracy: 0.9369 - val_loss: 51.1739 - val_accuracy: 0.5625
# Epoch 8/20
#  - ETA: 1:26 - loss: 0.0796 - accuracy: 0.9383
# Epoch 9/20
# 652/652 [==============================] - 121s 185ms/step - loss: 0.0813 - accuracy: 0.9340 - val_loss: 2.4809 - val_accuracy: 0.5625
# Epoch 10/20
# 652/652 [==============================] - 119s 183ms/step - loss: 0.0940 - accuracy: 0.9304 - val_loss: 0.4286 - val_accuracy: 0.8125
# Epoch 11/20
# 652/652 [==============================] - 120s 184ms/step - loss: 0.1115 - accuracy: 0.9229 - val_loss: 1.4153 - val_accuracy: 0.6875
# Epoch 12/20
# 652/652 [==============================] - 120s 185ms/step - loss: 0.0817 - accuracy: 0.9429 - val_loss: 0.7569 - val_accuracy: 0.6250
# Epoch 13/20
# 652/652 [==============================] - 121s 185ms/step - loss: 0.0827 - accuracy: 0.9392 - val_loss: 2.3872 - val_accuracy: 0.5625
# Epoch 14/20
# 652/652 [==============================] - 122s 187ms/step - loss: 0.0979 - accuracy: 0.9283 - val_loss: 1.3479 - val_accuracy: 0.6875
# Epoch 15/20
# 652/652 [==============================] - 122s 186ms/step - loss: 0.0871 - accuracy: 0.9400 - val_loss: 1.5807 - val_accuracy: 0.6250
# Epoch 16/20
# 652/652 [==============================] - 123s 188ms/step - loss: 0.0800 - accuracy: 0.9413 - val_loss: 0.6368 - val_accuracy: 0.8125
# Epoch 17/20
# 652/652 [==============================] - 123s 188ms/step - loss: 0.0798 - accuracy: 0.9408 - val_loss: 1.5583 - val_accuracy: 0.5000
# Epoch 18/20
# 652/652 [==============================] - 122s 188ms/step - loss: 0.0817 - accuracy: 0.9461 - val_loss: 0.8668 - val_accuracy: 0.6250
# Epoch 19/20
# 652/652 [==============================] - 123s 188ms/step - loss: 0.0769 - accuracy: 0.9461 - val_loss: 0.6531 - val_accuracy: 0.7500
# Epoch 20/20
# 652/652 [==============================] - 123s 189ms/step - loss: 0.0695 - accuracy: 0.9477 - val_loss: 0.8513 - val_accuracy: 0.6875

# %%
model.fit(x=shuffle_train, y=shuffle_labels_train, validation_data=(shuffle_valid, shuffle_labels_valid),epochs=5, batch_size=8, class_weight=class_weight, verbose=True)
# Out:
# Epoch 1/5
# 2/2 [==============================] - 1s 403ms/step - loss: 6.9215 - accuracy: 0.6429 - val_loss: 236.2038 - val_accuracy: 0.5000
# Epoch 2/5
# 2/2 [==============================] - 0s 52ms/step - loss: 6.5359 - accuracy: 0.7143 - val_loss: 429.8181 - val_accuracy: 0.5000
# Epoch 3/5
# 2/2 [==============================] - 0s 52ms/step - loss: 1.5992 - accuracy: 0.7857 - val_loss: 578.9362 - val_accuracy: 0.5000
# Epoch 4/5
# 2/2 [==============================] - 0s 51ms/step - loss: 1.3221e-19 - accuracy: 1.0000 - val_loss: 697.8722 - val_accuracy: 0.5000
# Epoch 5/5
# 2/2 [==============================] - 0s 52ms/step - loss: 5.2525e-28 - accuracy: 1.0000 - val_loss: 765.6359 - val_accuracy: 0.5000

# %%
model.save_weights('/media/andrea/Dati2/BigData/model.h5')

# %%
evaluation = model.evaluate(test)
print(f"Test Accuracy: {evaluation[1] * 100:.2f}%")

evaluation = model.evaluate(train)
print(f"Train Accuracy: {evaluation[1] * 100:.2f}%")

# %%
import os
os.environ["JAVA_HOME"] = "/usr/lib/jvm/java-11-openjdk-amd64" # Must corrispond to the current jdk used by colab
os.environ["SPARK_HOME"] = "/opt/spark/" # Must corrispond with the downloaded spark (1st line)

# %%
import findspark
findspark.init()
from pyspark.sql import SparkSession
import pyspark
import pyspark.rdd as rdd

#spark = SparkSession.builder.master("local[*]").getOrCreate()
sc = pyspark.SparkContext(master="spark://192.168.1.38:7077", appName="Dio")
sc.setLogLevel("Error")

# %%
del y

# %%
sc.stop()

# %%
import sys
import numpy as np
def func(kv):
    for v in kv[1]:
        if kv[0]<v:
            yield kv[0] + '-' + v,kv[1]
        else:
            yield v + '-' + kv[0],kv[1]
words = sc.parallelize([('A',['B','C', 'D']),('B',['A', 'C', 'D', 'E']),('C',['A', 'B', 'D', 'E']),('D',['A', 'B', 'C', 'E']),('E',['B', 'C', 'D'])])
els = words.flatMap(lambda kv: func(kv))
grouped = els.reduceByKey(lambda x,y:set(x)&set(y))
print(grouped.collect())

# %%
file1 = open('/home/andrea/Scrivania/X_train_test.txt', 'r')
Lines = file1.read()
Lines2 = [x.split(" ") for x in Lines]

# %%
import time
start_time = time.time()
words = sc.parallelize(Lines2)
data = words.map(lambda x:(len(x),(x,1)))
grouped = data.reduceByKey(lambda x,y:(x[0]+' '+y[0],x[1]+y[1]))
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# --- 4.135625839233398 seconds ---

# %%
data
